# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import os
from random import shuffle

#Original dataset path
ORIGINAL = 'Marcel_Train'

def label_img(img):
    word_label = img.split('-')[0]
    return word_label

#create training dataset which includes images and labels
training_data = []
def create_train_data():
    #training_data = []
    for img in os.listdir(ORIGINAL):
        label = label_img(img)
        path = os.path.join(ORIGINAL, img)
        img =  cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        #img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        training_data.append([np.array(img), np.array(label)])
        #printing images
      #  """
        #for i in range(12):
     #       plt.subplot(2, 2, 1),plt.imshow(img, cmap='gray')
     #       plt.title(label), plt.xticks([]), plt.yticks([])
     #       plt.show()
      #  """
        np.save('new_train_data.npy', training_data)
    return training_data

new_train_data = create_train_data()
new_train_data = np.asarray(new_train_data)
print(new_train_data[0:5])
print(new_train_data.shape)
# Out:
# [[array([[ 73,  68,  68, ...,  97, 119,  81],
#        [109, 109, 108, ...,  81, 112, 106],
#        [205, 205, 206, ...,  58,  70,  79],
#        ...,
#        [111, 111, 111, ...,  87,  79,  73],
#        [109, 108, 109, ...,  92,  86,  80],
#        [119, 118, 116, ...,  91,  82,  75]], dtype=uint8)
#   array('A', dtype='<U1')]
#  [array([[170, 170, 169, ..., 170, 169, 169],
#        [170, 171, 171, ..., 170, 170, 170],
#        [171, 170, 168, ..., 171, 169, 168],
#        ...,
#        [154, 154, 155, ..., 135, 134, 132],
#        [155, 151, 151, ..., 137, 141, 144],
#        [157, 155, 154, ..., 112,  82,  42]], dtype=uint8)
#   array('Point', dtype='<U5')]
#  [array([[161, 160, 158, ..., 160, 160, 161],
#        [161, 160, 160, ..., 162, 163, 162],
#        [160, 160, 160, ..., 161, 162, 163],
#        ...,
#        [ 39,  39,  39, ...,  15,  15,  16],
#        [ 47,  49,  49, ...,  16,  18,  19],
#        [ 50,  49,  49, ...,  16,  16,  16]], dtype=uint8)
#   array('Point', dtype='<U5')]
#  [array([[148, 150, 151, ..., 104, 102, 102],
#        [148, 149, 148, ...,  63,  65,  65],
#        [147, 149, 148, ..., 149, 150, 153],
#        ...,
#        [114, 121, 122, ..., 134, 127, 114],
#        [114, 120, 121, ..., 133, 132, 120],
#        [108, 115, 116, ..., 132, 132, 123]], dtype=uint8)
#   array('A', dtype='<U1')]
#  [array([[197, 199, 199, ..., 218, 201, 191],
#        [199, 201, 198, ..., 218, 201, 191],
#        [197, 198, 197, ..., 216, 199, 191],
#        ...,
#        [161, 163, 163, ...,  25,  26,  25],
#        [162, 162, 162, ...,  25,  26,  25],
#        [171, 170, 171, ...,  24,  24,  22]], dtype=uint8)
#   array('V', dtype='<U1')]]
# (4872, 2)

# %%
#Web reference for image processing
#http://creat-tabu.blogspot.com/2013/08/opencv-python-hand-gesture-recognition.html

# %%
ORIGINAL = 'Marcel_Train'

def label_img(img):
    word_label = img.split('-')[0]
    print(word_label)
    return word_label


#using Laplacian method
training_data = []
def create_train_data():
    #training_data = []
    for img in os.listdir(ORIGINAL):
        label = label_img(img)
        path = os.path.join(ORIGINAL, img)
        # img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(path, 0)
        laplacian = cv2.Laplacian(image, cv2.CV_64F)
        #img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        training_data.append([np.array(laplacian), np.array(label)])
        print(laplacian)
        """
        for i in range(12):
            plt.subplot(2, 2, 1),plt.imshow(img, cmap='gray')
            plt.title(label), plt.xticks([]), plt.yticks([])
            plt.show()
        """
    np.save('new_train_data_laplacian.npy', laplacian)
    return training_data

new_train_data_laplacian = create_train_data()
new_train_data_laplacian = np.asarray(new_train_data_laplacian)
print(new_train_data_laplacian[0:5])
print(new_train_data_laplacian.shape)
# Out:
#   File "<ipython-input-5-7160a08d0029>", line 21
#     printing laplacian
#                      ^
# SyntaxError: invalid syntax

# %%
#using sobelx method
training_data = []
def create_train_data():
    #training_data = []
    for img in os.listdir(ORIGINAL):
        label = label_img(img)
        path = os.path.join(ORIGINAL, img)
        # img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(path, 0)
        sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize = 5)
        #img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        training_data.append([np.array(sobelx), np.array(label)])
        #printing images
        """
        for i in range(12):
            plt.subplot(2, 2, 1),plt.imshow(img, cmap='gray')
            plt.title(label), plt.xticks([]), plt.yticks([])
            plt.show()
        """
    np.save('train_data_sobelx.npy', sobelx)
    return training_data

train_data_sobelx = create_train_data()
train_data_sobelx = np.asarray(train_data_sobelx)
print(train_data_sobelx[0:5])
print(train_data_sobelx.shape)
# Out:
# [[array([[ 0.000e+00, -1.200e+01,  1.900e+02, ...,  2.412e+03,  1.158e+03,
#          0.000e+00],
#        [ 0.000e+00, -2.000e+00,  1.550e+02, ...,  2.136e+03,  1.208e+03,
#          0.000e+00],
#        [ 0.000e+00, -9.000e+00,  8.300e+01, ...,  1.686e+03,  1.243e+03,
#          0.000e+00],
#        ...,
#        [ 0.000e+00, -1.600e+01, -5.000e+01, ..., -7.550e+02, -5.590e+02,
#          0.000e+00],
#        [ 0.000e+00, -3.700e+01, -8.100e+01, ..., -7.640e+02, -6.350e+02,
#          0.000e+00],
#        [ 0.000e+00, -5.800e+01, -1.080e+02, ..., -7.660e+02, -6.540e+02,
#          0.000e+00]])
#   array('A', dtype='<U1')]
#  [array([[ 0.000e+00,  2.000e+00,  4.200e+01, ..., -2.400e+01, -3.200e+01,
#          0.000e+00],
#        [ 0.000e+00, -1.000e+01,  4.200e+01, ..., -2.100e+01, -4.000e+01,
#          0.000e+00],
#        [ 0.000e+00, -3.300e+01,  4.900e+01, ..., -1.000e+00, -3.300e+01,
#          0.000e+00],
#        ...,
#        [ 0.000e+00, -1.110e+02, -1.770e+02, ..., -1.610e+02, -1.660e+02,
#          0.000e+00],
#        [ 0.000e+00, -1.270e+02, -1.900e+02, ..., -7.000e+02, -6.600e+02,
#          0.000e+00],
#        [ 0.000e+00, -1.420e+02, -1.980e+02, ..., -1.070e+03, -1.004e+03,
#          0.000e+00]])
#   array('Point', dtype='<U5')]
#  [array([[   0.,  -68.,  -46., ...,   34.,   30.,    0.],
#        [   0.,  -52.,  -45., ...,   38.,   32.,    0.],
#        [   0.,  -18.,  -35., ...,   39.,   32.,    0.],
#        ...,
#        [   0., -125., -188., ...,   32.,   64.,    0.],
#        [   0.,  -35., -125., ...,   43.,   68.,    0.],
#        [   0.,  -16., -110., ...,   48.,   68.,    0.]])
#   array('Point', dtype='<U5')]
#  [array([[   0.,   44.,   58., ...,   24.,   30.,    0.],
#        [   0.,   35.,   54., ...,   44.,   55.,    0.],
#        [   0.,   23.,   49., ...,   43.,   71.,    0.],
#        ...,
#        [   0.,  251.,  145., ...,  113., -528.,    0.],
#        [   0.,  263.,  159., ...,   40., -402.,    0.],
#        [   0.,  268.,  170., ...,   14., -338.,    0.]])
#   array('A', dtype='<U1')]
#  [array([[    0.,    60.,   444., ..., -1152., -1192.,     0.],
#        [    0.,    47.,   439., ..., -1160., -1185.,     0.],
#        [    0.,    30.,   453., ..., -1181., -1178.,     0.],
#        ...,
#        [    0.,    42.,    -8., ...,    13.,   -33.,     0.],
#        [    0.,    28.,     6., ...,   112.,    21.,     0.],
#        [    0.,    24.,    22., ...,   134.,    28.,     0.]])
#   array('V', dtype='<U1')]]
# (4872, 2)

# %%
#using sobely method
training_data = []
def create_train_data():
    #training_data = []
    for img in os.listdir(ORIGINAL):
        label = label_img(img)
        path = os.path.join(ORIGINAL, img)
        # img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(path, 0)
        sobely = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)  
        #img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        training_data.append([np.array(sobely), np.array(label)])
        #printing images
        """
        for i in range(12):
            plt.subplot(2, 2, 1),plt.imshow(img, cmap='gray')
            plt.title(label), plt.xticks([]), plt.yticks([])
            plt.show()
        """
    np.save('train_data_sobely.npy', sobely)
    return training_data

train_data_sobely = create_train_data()
train_data_sobely  = np.asarray(train_data_sobely )
print(train_data_sobely [0:5])
print(train_data_sobely .shape)
